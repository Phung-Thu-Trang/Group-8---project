# %%
import pandas as pd
import matplotlib as plt
import plotly.express as px

# %%
df=pd.read_csv(r"C:\Users\Dell\Downloads\Cleaned_Global_Cybersecurity_Threats_2015-2024.csv")

# %%
plt.rcParams['font.family'] ='Georgia'

# %%
print(df.head())            
print(df.info())          
print(df.describe())

# %%
df.isnull()
df.isna()

# %%
df.isna().any()

# %%
df.isna().sum()

# %%
print(df.isnull().sum())

# %%
print("Tổng số giá trị thiếu:", df.isnull().sum().sum())

# %%
print("Số dòng bị trùng:", df.duplicated().sum())

# %%
df[df.duplicated()]

# %%
attacks_per_year=df['Year'].value_counts().sort_index()
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(11,7))
plt.bar(attacks_per_year.index, attacks_per_year.values, color='#800026')
plt.xlabel("Year")
plt.ylabel("Number of attacks")
plt.title("Number of attacks over the years")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
attack_counts=df['Attack Type'].value_counts(normalize=True)*100
attack_counts=attack_counts.round(1)
print(attack_counts)

# %%
import plotly.io as pio
pio.renderers.default = 'browser'  # hoặc 'notebook_connected'

# %%
pio.renderers.default = 'notebook'


country_attacks = df['Country'].str.strip().value_counts().reset_index()
country_attacks.columns = ['Country', 'Attack count']

fig = px.choropleth(
    country_attacks,
    locations='Country',
    locationmode='country names',
    color='Attack count',
    color_continuous_scale= 'ylorrd',
    title='Map of most attacked countries'
)
fig.update_layout(margin={"l": 20, "r": 20, "t": 40 , "b": 20})
fig.show()

# %%
countries = df['Country'].unique()
print(countries)
